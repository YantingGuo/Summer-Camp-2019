# %% [markdown]
# <h1>XN Project 2019 Fall</h1>

# %% [markdown]
# <h2>Project Description</h2>

# %% [markdown]
# In this project, we are going to explore functions to automatically generate analysis report for research trend, which will help onclusive customers maintain a better pubulic relationship and win more market share in the furture.
# Our work have mainly divided into following parts:
# <ul>
# <li><i><b>Assumption</b></i></li>
#    Assume our client is apple,Inc, who want to know sentiments on the website about its product airpods.
# <li><i><b>Data Collection</b></i></li>
#     Based on the above assumption and our final goals, we collect data about airpods.including sources, date, author,     title, topic and content.
# <li><i><b>Exploratory Data Analysis</b></i></li>
#     EDA will be done to see how data spread and try fo find insights from raw data.
# <li><i><b>Sentiments Analysis</b></i></li>
#     Using Natural Language Process to do text mining, from the results of which, we will provides several visuals         about article frequency, authors, publications, competiotrs and co-mentioned terms which indicates features that     customer care about.
# <li><i><b>Automatical Reports</b></i></li>
#     On top of visuals, there are also corresponding reports to help customer understand those visuals and some           suggestions are provided to do market campaigns.

# %% [markdown]
# <h2>Exploratory Data Analysis</h2>

# %%
import numpy as np
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# '/Users/yanting/Downloads/github/yanting1'

# %%
raw = pd.read_csv('/Users/yanting/Desktop/XN_FinalDATA_Airpod - Sheet1.csv')

# %%
raw.head(10)
# Out:
#    Article_id   Topic                                              Title  \
# 0           1    Tech                                Airpods are Tragedy
# 1           2    Tech  Amazon Pursues Apple’s AirPods With Echo Bud W...
# 2           3    Tech       The latest Apple AirPods are finally on sale
# 3           4    Tech  Apple AirPods Review: Perfect Earbuds, but The...
# 4           5  Market                              Music to Apple’s Ears
# 5           6    Tech  AirPods, the world’s most popular wireless hea...
# 6           7    Tech  How did Apple’s AirPods go from mockery to mil...
# 7           8  Health       The truth behind claims Airpods cause cancer
# 8           9    Tech  Apple finds wearable ‘gimmicks’ really count a...
# 9          10    Tech  Everyone’s AirPods will die. We’ve got the tri...
#
#                                             Subtitle               Author  \
# 0  Apple claims that AirPods are building a “wire...     Caroline Haskins
# 1                                                NaN          Mark Gurman
# 2                                                NaN       Isabelle Kagan
# 3  Sleek and convenient, Apple’s wireless earbuds...           Brian Chen
# 4  Newly updated AirPods amped up non-iPhone busi...        Dan Gallagher
# 5                                                NaN                 Null
# 6  Back in 2016, Apple’s wireless earbuds were ri...         Elena Cresci
# 7                                                NaN        Zoë Schlanger
# 8  As sales of its signature product peak a big c...       Edward Helmore
# 9  We shouldn’t let Apple turn headphones into ex...  Geoffrey A. Fowler
#
#                  Source  Reviews       Date   \
# 0                  VICE      NaN  2019-05-06
# 1             Bloomberg      NaN  2019-09-25
# 2              USATODAY      NaN  2019-08-21
# 3       TheNewYorkTimes      NaN  2019-04-03
# 4  TheWallStreetJournal      NaN  2019-08-01
# 5                 Apple      NaN  2019-03-20
# 6          The Guardian   1061.0  2019-02-10
# 7                QUARTZ      NaN  2019-03-13
# 8          The Guardian      NaN  2019-05-05
# 9   The Washington Post   1034.0  2019-10-08
#
#                                                  URL  \
# 0  https://www.vice.com/en_us/article/neaz3d/airp...
# 1  https://www.bloomberg.com/news/articles/2019-0...
# 2  https://www.usatoday.com/story/tech/reviewedco...
# 3  https://www.nytimes.com/2019/04/03/technology/...
# 4  https://www.wsj.com/articles/music-to-apples-e...
# 5  https://www.apple.com/newsroom/2019/03/airpods...
# 6  https://www.theguardian.com/technology/shortcu...
# 7  https://qz.com/1572885/the-truth-behind-claims...
# 8  https://www.theguardian.com/technology/2019/ma...
# 9  https://www.washingtonpost.com/technology/2019...
#
#                                              Content
# 0  In each article of this column, we'll focus on...
# 1  Amazon.com Inc. revealed its rival to Apple In...
# 2  The latest model of AirPods—the ones that come...
# 3  Apple’s new AirPods, those tiny wireless earbu...
# 4  Apple Inc.’s AirPods met with no small amount ...
# 5  New AirPods Are Powered by the New H1 Chip and...
# 6  Of all the widely ridiculed tech products, App...
# 7  A story began circulating on internet news pla...
# 8  If Apple wants to prove to doubters that there...
# 9  “Sorry, we can’t help you,” said the Apple sto...

# %%
len(raw)
# Out:
# 65

# %%
import seaborn as sns

# %%
raw.Source.unique()
# Out:
# array(['VICE', 'Bloomberg', 'USATODAY', 'TheNewYorkTimes',
#        'TheWallStreetJournal', 'Apple', 'The Guardian', 'QUARTZ',
#        'The Washington Post', 'Forbes', 'Los Angeles Times', 'CNN',
#        'MEL Beta', 'COMPLEX', 'VOX', 'SoundGuys', '9to5Mac',
#        'DAILYMAIL.COM', 'The Atlantic', 'Digital Trends', 'arsTechnica',
#        "Tom'sguide", 'TheSun', 'New York Post', 'Cnet', 'CBS', 'Techno',
#        'NPR', 'Elite Daily', 'YOUREDM', 'The Verge', 'Business Insider',
#        'GottaBeMobile', 'VOA', 'HYPEBEAST', 'Engadget', 'Android Central',
#        'The Sydney Morning Herald', 'Inverse', 'BGR', 'WIRED'],
#       dtype=object)

# %%
len(raw.Source.unique())
# Out:
# 41

# %%
sns.set(font_scale=1, rc={"figure.figsize":(10,15)})
ax1 = sns.countplot(y="Source", data=raw)

# %%
import matplotlib.pyplot as plt

# %%
article_source5 = raw.Source.value_counts().sort_values(ascending = True).tail(5)
article_source5 = pd.DataFrame(article_source5)
ax2 = article_source5.plot(kind = 'bar',figsize = (10,5),width = 0.8,fontsize = 14,color = 'olive')
ax2.set_title('Top 3 Publications',fontsize = 20,pad = 30)
ax2.set_ylabel('Number of Articles',fontsize = 14)
ax2.xaxis.labelpad = 20
ax2.set_xlabel('Publications',fontsize = 14)
for i in ax2.patches:
    # get_width pulls left or right; get_y pushes up or down
    ax2.text(i.get_x()+0.4, i.get_height()+0.1, \
            str(i.get_height()), fontsize=11, color='dimgrey')

# %% [markdown]
# From the above figure, in terms of airpords articles, we can find Forbes has more articles than other publications, releasing 9 in 2019.

# %%
sns.set(style="darkgrid")
sns.set(rc={'figure.figsize':(10,8)})
ax3 = sns.countplot(y="Topic", data=raw)
ax3.set_title('Topics Frequency',fontsize = 20,pad = 15)
# Out:
# Text(0.5, 1.0, 'Topics Frequency')

# %% [markdown]
# Most articles involving airpods are assigned in tech section.

# %%
# packages
import nltk, urllib, requests, string, re
from nltk import word_tokenize
from nltk.corpus import stopwords
from matplotlib.pyplot import figure
import matplotlib.pyplot as plt
import pandas as pd
from bs4 import BeautifulSoup
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /Users/yanting/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
raw['word_count'] = raw['Content'].apply(lambda x: len(str(x).split(" ")))
raw[['Content','word_count']].head()
# Out:
#                                              Content  word_count
# 0  In each article of this column, we'll focus on...        3014
# 1  Amazon.com Inc. revealed its rival to Apple In...         121
# 2  The latest model of AirPods—the ones that come...          61
# 3  Apple’s new AirPods, those tiny wireless earbu...         615
# 4  Apple Inc.’s AirPods met with no small amount ...          73

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.font_manager import FontProperties
import statistics
import math
import numpy as np

# %%
total_articles = sum(raw.word_count)
avg_words = statistics.mean(raw.word_count)

left, width = .25, .5
bottom, height = .25, .5
right = left + width
top = bottom + height
font = FontProperties()
font.set_family('serif')
font.set_name('Arial Rounded MT')
font.set_style('italic')
plt.figure(figsize=(18,20),facecolor='lightblue')
grid = plt.GridSpec(3, 4, wspace=0.5, hspace=0.5)
ax = plt.subplot(grid[1:2,0])
ax.text(left+0.1, top+0.1, 'Total Articles',
        horizontalalignment='center',
        verticalalignment='center',fontproperties=font,
        fontsize=15, color='darkgreen', 
        transform=ax.transAxes)
ax.text(left+0.1, top-0.1,total_articles,
        horizontalalignment='center', 
        verticalalignment='center',
        fontsize=30, fontweight='bold', color='darkblue',
        transform=ax.transAxes)
ax.text(left+0.1, bottom+0.1, 'Average Words Per Article',
        horizontalalignment='center', 
        verticalalignment='center',fontproperties=font,
        fontsize=15, color='darkgreen',
        transform=ax.transAxes)
ax.text(left+0.1, bottom-0.1, avg_words,
        horizontalalignment='center', 
        verticalalignment='center',
        fontsize=30, fontweight='bold', color='darkblue',
        transform=ax.transAxes)
plt.axis('off')
fig=plt.subplot(grid[1:2,1:3])
plt.rcParams['axes.facecolor'] = 'white'
fig.patch.set_alpha(0.1)
plt.plot(raw.word_count,color = 'darkblue', linewidth=5)
plt.title("Words Count For Articles",pad = 15,fontsize = 15)
plt.xlabel("Article Id",fontsize=13)
plt.ylabel("Words",fontsize=13)
plt.grid(False)
# Out:
# /anaconda3/lib/python3.7/site-packages/matplotlib/font_manager.py:1241: UserWarning: findfont: Font family ['Arial Rounded MT'] not found. Falling back to DejaVu Sans.
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
def title_key_word(s):
    raw1 = BeautifulSoup(s, 'html.parser').get_text()
    raw1=raw1.lower()
    raw1=re.sub(r'\d+', '', raw1)
    tokens1 = word_tokenize(raw1)
    sw1 = stopwords.words('English')
    new_token_1=list()
    for t in tokens1:
        if t not in sw1:
            new_token_1.append(t)
    punc=list(string.punctuation)
    manualcheck= ['“','”','’',"n't","'m","th","'d","'s","eant",'priyanka','bangalore','std']
    punc.extend(manualcheck)
    new_token_2=list()
    for t in new_token_1:
        if t not in punc:
            new_token_2.append(t)
    tagged = nltk.pos_tag(new_token_2)
    t1=list()
    for com in tagged:
        if com[1]=='NN' or com[1]=='NNS' or com[1]=='NNP' or com[1]=='NNPS':
            t1.append(com[0])
    freq= nltk.FreqDist(t1)
    tryo = pd.DataFrame(list(dict(freq).items()))
    if tryo.empty:
        result=list()
    else:
        tryo=tryo.sort_values(by=1, ascending=False)
        tryo.columns = ['Words', 'freq']
        if len(list(tryo['Words']))<1:
            result=list(tryo['Words'])
        else:
            df=tryo[0:1]
            result=list(df['Words'])
    return(result)

# %%
titles = ''
for i in raw.Title:
    titles = titles + ' ' + i
print(titles)
# Out:
#  Airpods are Tragedy Amazon Pursues Apple’s AirPods With Echo Bud Wireless Headphones The latest Apple AirPods are finally on sale Apple AirPods Review: Perfect Earbuds, but They Don’t Last Music to Apple’s Ears AirPods, the world’s most popular wireless headphones, are getting even better How did Apple’s AirPods go from mockery to millennial status symbol? The truth behind claims Airpods cause cancer Apple finds wearable ‘gimmicks’ really count as iPhone slips Everyone’s AirPods will die. We’ve got the trick to replacing them. Apple Readies Camera-Focused Pro iPhones, New iPads, Larger MacBook Pro AirPods 3 May Launch In Days, Called AirPods Pro, With Cool New Features Apple’s AirPods With Wireless Charging Case Are Only $169 Apple Accidentally Leaks AirPods 3 With New Design, Maybe Noise Canceling Powerbeats Pro Earphones Are Now $50 Off By The Numbers: How Tariffs On Airpods & Apple Watch Impacts Apple's Profits Apple unveils new AirPods with extended talk time and wireless charging Move Over, AirPods 2: Huawei Reveals Show-Stopping FreeBuds 3 With Cool Features AirPods are on sale at their lowest price ever HOW AIRPODS BECAME THE ULTIMATE FAKE-RICH-PERSON FLEX Samsung Beats Apple As AirPods Face Embarrassing Defeat AirPods 'Rich People' Memes Come Pouring in After Christmas AirPods, explained New Apple Airpods review: are they any better?  Comment: For AirPods early adopters, Apple’s hit wireless earbuds are showing their age Are wireless earbuds dangerous? Experts warn that Apple’s AirPods could send an electromagnetic field through your brain - as 250 scientists sign petition to regulate trendy tech Workers Love AirPods Because Employers Stole Their Walls Apple’s next AirPods case may be waterproof and let you recharge an Apple Watch Apple’s updated AirPods are here, cost $199 with new wireless charging case New AirPods case looks just like a retro Apple Macintosh monitor AirPods 2 vs AirPods: What’s Different?  Apple to launch AirPods Pro earbuds with new design and noise-cancelling tech in two weeks, rumours say These earbuds feel and look just like AirPods but cost a lot less The best Apple AirPods and Beats Wireless headphone deals People love AirPods so much they spend more than half a billion a year replacing them This Wacky Charging Case Juices Your iPhone and AirPods at Once AirPods vs. Powerbeats Pro: The best wireless earphones are… Apple to Release Expensive AirPods Upgrade Apple may launch high-end AirPods Pro later this month The Case for Wearing AirPods All the Time AirPods 2 Have Never Looked Lovelier: Apple Premieres Ad With Super-Cute Cases Tiny Tech Tips: Finding The Perfect Headphones Google Pixel Buds 2 Vs. Apple AirPods Highlights A Couple Big Differences LEAK: APPLE AIRPODS PRO WITH NOISE CANCELLATION COMING SOON Apple rumored to launch new AirPods Pro headphones at end of October Apple will reportedly launch new AirPods as early as this month as a growing number of tech companies go to war for your ears Apple’s AirPods have little to fear from its rivals 4 Reasons to Wait for AirPods 3 & 2 Reasons Not To Apple's AirPods Will Not Escape Trump's China Tariffs Apple just unveiled 'Pro' AirPods that cost almost $100 more and have a brand-new design Apple Officially Announces the AirPods Pro (UPDATE) What happens when an AirPod gets lost in a NYC subway station? [Video] Apple's $249 AirPods Pro pack noise cancellation and hands-free Siri Apple AirPods Lose Power Fast, And There’s No Cheap Fix The Best Wireless Headphones (That Aren’t AirPods) These AirPod alternatives offer superb audio and battery life for $40 Apple AirPods' poor design hurts our wallets, and the environment 3 Headphones That Cost 50% Less Than Airpods And Are Just As Good The worst thing about Apple’s AirPods can be fixed for $10 10 wireless earbud options that cost way less than AirPods Apple AirPods 2019 review Review: Apple Airpods(2019) AirPods Are a Tragedy Apple’s new Powerbeats are the biggest threat to AirPods Save when you sc ...

# %%
min(raw.word_count)
min_count = 0
for i in raw.word_count:
    if i == min(raw.word_count):
        min_count += 1
print(min_count)
max(raw.word_count)
max_count = 0
for i in raw.word_count:
    if i == max(raw.word_count):
        max_count += 1
print(max_count)
# Out:
# 1
# 1

# %%
print('                                        Article Report                               ')
print('    This is a report for {0}. There are {1} articles about {0},every article contains attitudes or reviews with various words.\n    Based on the data we have, articles about {0} have {2} words on average even though {3} article has {4} words and {5} article has {6} words. Overall, 75% articles has less than {7} words.'.format(title_key_word(titles)[0],total_articles, math.ceil(avg_words),min_count,min(raw.word_count),max_count,max(raw.word_count),math.ceil(np.percentile(raw.word_count,75))))
# Out:
#                                         Article Report
#     This is a report for airpods. There are 40313 articles about airpods,every article contains attitudes or reviews with various words.
#     Based on the data we have, articles about airpods have 621 words on average even though 1 article has 61 words and 1 article has 3014 words. Overall, 75% articles has less than 718 words.

# %%
def key_word(s):
    rawdata = BeautifulSoup(s, 'html.parser').get_text() 
    rawdata=rawdata.lower() 
    rawdata=re.sub(r'\d+', '', rawdata) 
    tokens = word_tokenize(rawdata) 
    list0 = stopwords.words('English')
    list1 = ['airpods—the','case—are']
    sw = list0
    sw.extend(list1)
    new_token=list()
    for t in tokens:
        if t not in sw:
            new_token.append(t)
    punc=list(string.punctuation) # list puntuations from string package
    punc.append('“')  # add other signs that do not contained in sting list
    punc.append('”')
    punc.append('’')
    punc.append('\'') 
    punc.append("n't")
    punc.append("'m")
    punc.append("th")
    punc.append("'d")
    punc.append("'ve")
    punc.append("'re")
    punc.append("'ll")
    punc.append("--")
    punc.append("-a")
    punc.append("'s")
    punc.append("\"")
    punc.append("re")
    punc.append("will")
    punc.append("people")
    punc.append("products")
    punc.append("product")
    punc.append("years")
    punc.append("companies")
    punc.append("company")
    new_token2=list()
    for t in new_token:
        if t not in punc:
            new_token2.append(t) # this list contain key words
    tagged = nltk.pos_tag(new_token2)
    l = list()
    for x in tagged:
        if x[1] =='NN' or x[1] =='NNS':
            l.append(x[0])
    return l

# %%
term_count = {}
for i in raw.Content:
    words = key_word(i)
    for word in words:
        if word not in term_count:
            term_count[word] = 1
        else:
            term_count[word] = term_count[word] + 1
data = pd.DataFrame.from_dict(term_count, orient='index')
data = data.reset_index()
data.columns = ['Terms','Count']
terms =data.sort_values(by = ['Count'],ascending = False).head(20)
terms = terms[2:]
terms1=terms.sort_index()
terms1
# Out:
#           Terms  Count
# 61        music     59
# 63        phone     51
# 67      battery     68
# 71          way     46
# 78   headphones    160
# 87         pair     53
# 93       design     63
# 98         life     76
# 104    wireless    164
# 121        case    202
# 122     earbuds     52
# 154      airpod     47
# 262      iphone     70
# 440        buds     67
# 444       hours     75
# 473        time     71
# 506     devices     47
# 523        year     49

# %%
terms.iloc[2,1]
# Out:
# 160

# %%
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
text = " ".join(content for content in raw.Content)
stopwords1 = set(STOPWORDS)
# Generate a word cloud image
wordcloud = WordCloud(stopwords=stopwords1, background_color="white",colormap = 'viridis').generate(text)

# %%
font = FontProperties()
font.set_family('serif')
font.set_name('Arial Rounded MT')
font.set_style('italic')
plt.figure(figsize=(15,20),facecolor='white')
ax = plt.subplot(2,1,1)
plt.title('Wordcloud of All Contents', fontsize = 20, pad=30)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
fig=plt.subplot(2,1,2)
sns.set(rc={'figure.figsize':(15,10)})
sns.set_context("poster", font_scale = 0.8, rc={"grid.linewidth": 1})
ax4 = sns.barplot(x="Terms", y="Count", data=terms1, palette="rocket")
for item in ax4.get_xticklabels():
    item.set_rotation(80)
ax4.set_title('Top 20 Co_Mentioned Terms',fontsize = 20,pad = 30)
plt.grid(False)

# %%
print('                                  Report about Co-mentioned Terms                          ')
print('    Advertorials with influential terms sound more likely to have a better result of market campaign.\n    By learning the {0} articles collected, we find several words are repetitive mentioned. The Wordcloud figure above gives some clues. Words in bigger size are mentioned more than the other words. Then, moving forward to the bar plot below, We find the top three co-mentioned terms are {1},{2},{3}. Especially, {1} was mentioned {4} times, {2} was mentioned {5} times and {3} was mentioned {6} times. '.format(len(raw),terms.iloc[0,0],terms.iloc[1,0],terms.iloc[2,0],terms.iloc[0,1],terms.iloc[1,1],terms.iloc[2,1]))
# Out:
#                                   Report about Co-mentioned Terms
#     Advertorials with influential terms sound more likely to have a better result of market campaign.
#     By learning the 65 articles collected, we find several words are repetitive mentioned. The Wordcloud figure above gives some clues. Words in bigger size are mentioned more than the other words. Then, moving forward to the bar plot below, We find the top three co-mentioned terms are case,wireless,headphones. Especially, case was mentioned 202 times, wireless was mentioned 164 times and headphones was mentioned 160 times.

# %%
raw.Content[0]
# Out:
# 'In each article of this column, we\'ll focus on one item that could conceivably be discovered by someone 1,000 years from now, and try to explain where this item came from, where it\'s going, and what its existence explains about our current moment. AirPods are a product of the past. They\'re plastic, made of some combination of carbon, hydrogen, oxygen, nitrogen, chlorine, and sulfur. They’re tungsten, tin, tantalum, lithium, and cobalt. The particles that make up these elements were created 13.8 billion years ago, during the Big Bang. Humans extract these elements from the earth, heat them, refine them. As they work, humans breathe in airborne particles, which deposit in their lungs. The materials are shipped from places like Vietnam, South Africa, Kazakhstan, Peru, Mexico, Indonesia, and India, to factories in China. A literal city of workers creates four tiny computing chips and assembles them into a logic board. Sensors, microphones, grilles, and an antenna are glued together and packaged into a white, strange-looking plastic exoskeleton. These are AirPods. They’re a collection of atoms born at the dawn of the universe, churned beneath the surface of the earth, and condensed in an anthropogenic parallel to the Big Crunch—a proposed version of the death of the universe where all matter shrinks and condenses together. Workers are paid unlivable wages in more than a dozen countries to make this product possible. Then it’s sold by Apple, the world’s first trillion-dollar company, for $159 USD. For roughly 18 months, AirPods play music, or podcasts, or make phone calls. Then the lithium-ion batteries will stop holding much of a charge, and the AirPods will slowly become unusable. They can’t be repaired because they\'re glued together. They can’t be thrown out, or else the lithium-ion battery may start a fire in the garbage compactor. They can’t be easily recycled, because there’s no safe way to separate the lithium-ion battery from the plastic shell. Instead, the AirPods sit in your drawer forever.Kyle Wiens, CEO of iFixit, which does electronics teardowns and sells repair tools and parts, told Motherboard that AirPods are “evil.” According to the headphones review team at Rtings.com, AirPods are "below-average" in terms of sound quality. According to people on every social media platform, AirPods are a display of wealth. But more than a pair of headphones, AirPods are an un-erasable product of culture and class. People in working or impoverished economic classes are responsible for the life-threatening, exhaustive, violent work of removing their parts from the ground and assembling them. Meanwhile, people in the global upper class design and purchase AirPods. Even if you only own AirPods for a few years, the earth owns them forever. When you die, your bones will decompose in less than a century, but the plastic shell of AirPods won’t decompose for at least a millennium. Thousands of years in the future, if human life or sentient beings exist on earth, maybe archaeologists will find AirPods in the forgotten corners of homes. They’ll probably wonder why they were ever made, and why so many people bought them. But we can also ask ourselves those same questions right now. Why did we make technology that will live for 18 months, die, and never rot? THE SOCIAL LIFE OF AIRPODS AirPods aren’t the most expensive pair of wireless earbuds on the market. Some luxury wireless earbuds cost upwards of $730. Other companies like Sennheiser sell wireless earbuds for $300. Bose sells its pair for about $200. Mark Henny, the head of headphone reviews for Rtings.com, said that the AirPods offer a lot of value for the price point despite a rating of "below average" sound quality. “You also have much cheaper models, but for the quality of the craftsmanship of the AirPods, from the case to the actual earbuds, and also for the reliable wireless connection, the battery life—the price of the AirPods is actually pretty fair,” Henny told Motherboard. A ...

# %%
raw.word_count[0]
# Out:
# 3014

# %%
type(raw.word_count)
# Out:
# pandas.core.series.Series

# %%
key_word(raw.Content[0])
# Out:
# ['article',
#  'column',
#  'focus',
#  'item',
#  'someone',
#  'try',
#  'item',
#  'existence',
#  'explains',
#  'moment',
#  'airpods',
#  'plastic',
#  'combination',
#  'carbon',
#  'hydrogen',
#  'oxygen',
#  'nitrogen',
#  'chlorine',
#  'sulfur',
#  'tin',
#  'tantalum',
#  'lithium',
#  'cobalt',
#  'particles',
#  'elements',
#  'bang',
#  'humans',
#  'elements',
#  'refine',
#  'work',
#  'humans',
#  'particles',
#  'lungs',
#  'materials',
#  'places',
#  'peru',
#  'mexico',
#  'indonesia',
#  'factories',
#  'city',
#  'workers',
#  'chips',
#  'assembles',
#  'board',
#  'sensors',
#  'grilles',
#  'plastic',
#  'exoskeleton',
#  'airpods',
#  'collection',
#  'atoms',
#  'dawn',
#  'universe',
#  'surface',
#  'earth',
#  'parallel',
#  'crunch—a',
#  'version',
#  'death',
#  'matter',
#  'shrinks',
#  'workers',
#  'wages',
#  'dozen',
#  'countries',
#  'apple',
#  'world',
#  'months',
#  'airpods',
#  'music',
#  'podcasts',
#  'phone',
#  'lithium-ion',
#  'batteries',
#  'charge',
#  'airpods',
#  'lithium-ion',
#  'battery',
#  'fire',
#  'garbage',
#  'compactor',
#  'way',
#  'lithium-ion',
#  'battery',
#  'plastic',
#  'shell',
#  'airpods',
#  'wiens',
#  'electronics',
#  'repair',
#  'tools',
#  'parts',
#  'airpods',
#  'headphones',
#  'review',
#  'team',
#  'rtings.com',
#  'airpods',
#  'terms',
#  'quality',
#  'media',
#  'platform',
#  'airpods',
#  'wealth',
#  'pair',
#  'headphones',
#  'airpods',
#  'culture',
#  'class',
#  'classes',
#  'violent',
#  'work',
#  'parts',
#  'ground',
#  'class',
#  'design',
#  'purchase',
#  'airpods',
#  'airpods',
#  'bones',
#  'century',
#  'plastic',
#  'shell',
#  'airpods',
#  'thousands',
#  'life',
#  'beings',
#  'airpods',
#  'corners',
#  'homes',
#  'questions',
#  'technology',
#  'months',
#  'life',
#  'airpods',
#  'airpods',
#  'pair',
#  'wireless',
#  'market',
#  'luxury',
#  'wireless',
#  'cost',
#  'upwards',
#  'sennheiser',
#  'sell',
#  'wireless',
#  'mark',
#  'head',
#  'headphone',
#  'rtings.com',
#  'airpods',
#  'lot',
#  'value',
#  'price',
#  'point',
#  'rating',
#  'sound',
#  'quality',
#  'models',
#  'airpods',
#  'case',
#  'earbuds',
#  'connection',
#  'battery',
#  'price',
#  'airpods',
#  'motherboard',
#  'media',
#  'airpods',
#  'owners',
#  'part',
#  'joke',
#  'fact',
#  'airpods',
#  'clothes',
#  'size',
#  'purchase',
#  'airpods',
#  'afford',
#  'buy',
#  'irony',
#  'recycle',
#  'airpods',
#  'objects',
#  'person',
#  'ear',
#  'lots',
#  'airpods',
#  'airpods',
#  'stop',
#  'charge',
#  'airpods',
#  'someone',
#  'problem',
#  'airpods',
#  'earth',
#  'airpods',
#  'embodies',
#  'way',
#  'picture',
#  'idea',
#  'wealth',
#  'multimillionaires',
#  'airpods',
#  'idea',
#  'anyone',
#  'demonstrate',
#  'wealth',
#  'world',
#  'pair',
#  'airpods',
#  'sense',
#  'deal',
#  'tiktok',
#  'sentiment',
#  'pretend',
#  'flush',
#  'airpods',
#  'toilet',
#  'airpod',
#  'iteration',
#  'airpods',
#  'god',
#  'picture',
#  'someone',
#  'situation',
#  'joke',
#  'airpods',
#  'celebrities',
#  'environment',
#  'listen',
#  'reality',
#  'airpods',
#  'isolation',
#  'rtings.com',
#  'airpods',
#  'quality',
#  'meme',
#  'airpods',
#  'take',
#  'show',
#  'world',
#  'way',
#  'fun',
#  'lives',
#  'wireless',
#  'earbuds',
#  'airpods',
#  'brands',
#  'subtlety',
#  'antennaless',
#  'apple',
#  'looks',
#  'head',
#  'toothbrush',
#  'airpod',
#  'reviews',
#  'appearance',
#  'controversial.',
#  'strange-looking',
#  'ignore',
#  'appearance',
#  'airpods',
#  'statement',
#  'reality',
#  'statement',
#  'airpods',
#  'reasons',
#  'airpods',
#  'headphones',
#  'apple',
#  'jack',
#  'headphones',
#  'dongle',
#  'apple',
#  'lightning',
#  'headphones',
#  'appearance',
#  'airpods',
#  'instance',
#  'twitter',
#  'user',
#  'bloodorgy',
#  'earrings',
#  'airrings',
#  'dozens',
#  'merchants',
#  'cases',
#  'airpods',
#  'luxury',
#  'gucci',
#  'vuitton',
#  'supreme',
#  'counterfeit',
#  'none',
#  'airpod',
#  'accessories',
#  'apple',
#  'canon',
#  'image',
#  'etsy',
#  'case',
#  'airpod',
#  'owners',
#  'status',
#  'airpods',
#  'notion',
#  'demonstrate',
#  'wealth',
#  'wealth',
#  'school',
#  'airpods',
#  'reddit',
#  'crispviolet',
#  'motherboard',
#  'subreddit',
#  'r/airpods',
#  'airpods',
#  'wealth',
#  'friends',
#  'airpods',
#  'headphones',
#  'sound',
#  'price.',
#  'redditor',
#  'weab',
#  'motherboard',
#  'message',
#  'airpods',
#  'something',
#  'fact',
#  'bit',
#  'think',
#  'bougie',
#  'toxic',
#  'point',
#  'everyone',
#  'la',
#  'disposability',
#  'airpods',
#  'mirrors',
#  'fact',
#  'labor',
#  'labor',
#  'refers',
#  'workers',
#  'whims',
#  'capitalists',
#  'hand',
#  'market.',
#  'demand',
#  'service',
#  'work',
#  'workers',
#  'workers',
#  'part',
#  'production',
#  'process',
#  'writers',
#  'harry',
#  'magdoff',
#  'article',
#  'review',
#  'culmination',
#  'labor',
#  'mines',
#  'refinery',
#  'facilities',
#  'facilities',
#  'workers',
#  'thousands',
#  'thousands',
#  'dozens',
#  'countries',
#  'brazil',
#  'indonesia',
#  'thailand',
#  'china',
#  'malaysia',
#  'brazil',
#  'bolivia',
#  'peru',
#  'india',
#  'philippines',
#  'russia',
#  'japan',
#  'germany',
#  'belgium',
#  'macedonia',
#  'korea',
#  'canada',
#  'netherlands—in',
#  'order',
#  'refine',
#  'materials',
#  'electronics',
#  'cost',
#  'assembles',
#  'half',
#  'iphones',
#  'business',
#  'insider',
#  'apple',
#  'luxshare',
#  'airpods',
#  'factory',
#  'zhengzhou',
#  'iphone',
#  'city.',
#  'business',
#  'insider',
#  'facilities',
#  'salaries',
#  'month',
#  'apple',
#  'cobalt',
#  'tantalum—which',
#  'power',
#  'lithium-ion',
#  'batteries',
#  'conductors',
#  'boards',
#  'congo',
#  'drc',
#  'reports',
#  'child',
#  'labor',
#  'worker',
#  'deaths',
#  'apple',
#  'materials',
#  'mines',
#  'consumers',
#  'think',
#  'stories',
#  'apple',
#  'details',
#  'chain',
#  'marx',
#  'meant',
#  'satisfy',
#  'value',
#  'use',
#  'definition',
#  'survival',
#  'value',
#  'labor',
#  'apple',
#  'value',
#  'dirt',
#  'blood',
#  'sweat',
#  'tears',
#  'packaging',
#  'value',
#  'aches',
#  'pains',
#  'commodities',
#  'airpods',
#  'airpods',
#  'message',
#  'wealth',
#  'airpods',
#  'value',
#  'chain',
#  'production',
#  'place',
#  'apple',
#  'story',
#  'apple',
#  'airpods',
#  'part',
#  'vision',
#  'wireless',
#  'future.',
#  'apple',
#  'introduces',
#  'airpods',
#  'headphones',
#  'apple',
#  'argues',
#  'airpods',
#  'liberation',
#  'things',
#  'plastic',
#  'wires',
#  'wire',
#  'headphones',
#  'apple',
#  'sales',
#  'liberation',
#  'straightforward',
#  'airpods',
#  'iphone',
#  'jack',
#  'earbuds',
#  'iphone',
#  'macbook',
#  'apple',
#  'watch',
#  'device',
#  'airpods',
#  'luxury',
#  'convenient',
#  'headphone',
#  'jack',
#  'apple',
#  'iphone',
#  'destroying',
#  'nuisance',
#  'headphone',
#  'jacks',
#  'costs',
#  'system',
#  'creates',
#  'life',
#  'try',
#  'recycle',
#  'airpods',
#  'worker',
#  'plant',
#  'engage',
#  'mundane',
#  'task',
#  'lithium-ion',
#  'battery',
#  'plastic',
#  'try',
#  'airpods',
#  'risk',
#  'fire',
#  'garbage',
#  'compactor',
#  'facility',
#  'airpods',
#  'earth',
#  'crust',
#  'airpods',
#  'moment',
#  'airpods',
#  'months',
#  'ion',
#  'battery',
#  'obsolescence',
#  'category',
#  'obsolescence',
#  'failure',
#  'motherboard',
#  'knew',
#  'months',
#  'box',
#  'battery',
#  'are.',
#  'airpods',
#  'apple—at',
#  'marketing',
#  'perspective',
#  'music',
#  'distribution',
#  'creation',
#  'ipod',
#  'music',
#  'marketplace',
#  'itunes',
#  'proliferation',
#  'mp',
#  'headphones',
#  'point',
#  'ipod',
#  'advertisements',
#  'apple',
#  'airpods',
#  'headphones',
#  'world',
#  'two-minute',
#  'video',
#  'audio',
#  'quality',
#  'sentence',
#  'course',
#  'airpods',
#  'sound.',
#  'core',
#  'apple',
#  'airpods',
#  'fact',
#  'technology',
#  'apple',
#  'vice',
#  'president',
#  'marketing',
#  'philip',
#  'schiller',
#  'airpods',
#  'chip',
#  'accelerometers',
#  'sensors',
#  'microphones',
#  'tour',
#  'minute',
#  'airpods',
#  'iphones',
#  'headphones',
#  'wireless',
#  'chip',
#  'things',
#  'communicate',
#  'phone',
#  'computer',
#  'device',
#  'system',
#  'preferences',
#  'airpods',
#  'siri',
#  'phone',
#  'calls',
#  'technology',
#  'airpods',
#  'bluetooth',
#  'radio',
#  'waves',
#  'data',
#  'sound',
#  'device',
#  'device',
#  'jim',
#  'intel',
#  'employee',
#  'motherboard',
#  'wireless',
#  'bluetooth',
#  'capabilities',
#  'luxury',
#  'technology',
#  'apple',
#  'motherboard',
#  'requests',
#  'kardach',
#  'thinks',
#  'advertisements',
#  'luxury',
#  'cars',
#  'car',
#  'brag',
#  'anything',
#  'kardach',
#  'cost',
#  'radio',
#  'jaguar',
#  'dollar',
#  'things',
#  'airpods',
#  'stalk',
#  'area',
#  'straightforward',
#  'wireless',
#  'technology',
#  'twenty',
#  'harald',
#  'son',
#  'gorm',
#  'kardach',
#  'technology',
#  'king',
#  'denmark',
#  'century',
#  'ad',
#  'kardach',
#  'goal',
#  'technology',
#  'radio',
#  'technologies',
#  'bluetooth',
#  'ancient',
#  'denmark',
#  'kingdom',
#  'marketing',
#  'guy',
#  'hey',
#  'call',
#  'program',
#  'bluetooth',
#  'kardach',
#  'stone.',
#  'sharpie',
#  'sharpie',
#  'cellphone',
#  'notebook',
#  'hand',
#  'cellphone',
#  'notebook',
#  'perfect',
#  'this.',
#  'technology',
#  'archaeology',
#  'stories',
#  'create',
#  'airpods',
#  'technology',
#  'months',
#  'earth',
#  'course',
#  'airpods',
#  'use',
#  'trash',
#  'single-use',
#  'plastics—like',
#  'water',
#  'bottles',
#  'cups',
#  'packaging—are',
#  'convenient',
#  'consumers',
#  'floors',
#  'scientists',
#  'plasticine',
#  'electronics',
#  'apple',
#  'repairability',
#  'line',
#  'efforts',
#  'boot',
#  'iphone',
#  'macbook',
#  'refurbishers',
#  'marketplace',
#  'scale',
#  'system',
#  'longevity',
#  'make',
#  'die',
#  'airpods',
#  'market',
#  'jokes',
#  'wealth',
#  'truth',
#  'airpods',
#  'wealth',
#  'manifestations',
#  'system',
#  'headphones',
#  'death',
#  'produce',
#  'airpods',
#  'anything',
#  'capitalism']

# %%
def countWords(A):
   dic={}
   for x in A:
       if not x in  dic:        
          dic[x] = A.count(x)
   return dic

dic = countWords(key_word(raw.Content[0]))
sorted_items=sorted(dic.items(),key=lambda x: x[1],reverse=True)  
sorted_items = pd.DataFrame.from_dict(sorted_items)
sorted_items.columns = {'Terms','Frequency'}
sorted_items.head()
# Out:
#         Terms  Frequency
# 0     airpods         75
# 1       apple         22
# 2  headphones         12
# 3      wealth          9
# 4  technology          9

# %%
from datetime import datetime
datetime_object1 = datetime.strptime(raw.Date[0], '%Y-%m-%d')
print(datetime_object.strftime("%b %d %Y "))
# Out:
# May 06 2019

# %%
release_date = '2019-03-20'
datetime_object2 = datetime.strptime(release_date, '%Y-%m-%d')
month_diff = datetime_object1.month-datetime_object2.month
month_diff
# Out:
# 2

# %%
abs(datetime_object2.month-datetime_object1.month)
# Out:
# 2

# %%
print('                  Individual Report                     ')
print('This is a individual report about {0}, which was written by {1} in {2}, almost {3} months {4} 2nd generation released.\nEven though there are {5} words in this article, {6} mentioned {7}, {8} and {9} for {10} times. Apart from these three words, there are also several words mentioned more than once. Below is the barplot indicating the top 10 co-mentioned terms and its frequency. '.format(sorted_items.Terms[0],raw.Author[0],datetime_object1.strftime('%b %d %Y'),abs(month_diff), 'after' if month_diff > 0 else 'before', raw.word_count[0],raw.Author[0].split()[1],sorted_items.Terms[1],sorted_items.Terms[2],sorted_items.Terms[3],sum(sorted_items.Frequency[:3])))
# Out:
#                   Individual Report
# This is a individual report about airpods, which was written by Caroline Haskins in May 06 2019, almost 2 months after 2nd generation released.
# Even though there are 3014 words in this article, Haskins mentioned apple, headphones and wealth for 109 times. Apart from these three words, there are also several words mentioned more than once. Below is the barplot indicating the top 10 co-mentioned terms and its frequency.

# %%
sns.barplot(x="Terms", y="Frequency", data=sorted_items[1:11], palette="muted")
plt.title("Top 10 Co-mentioned Terms",pad = 15,fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Top 10 Co-mentioned Terms')

# %%
from datetime import datetime
datetime_object = datetime.strptime(raw.Date[0], '%Y-%m-%d')
print(datetime_object.strftime("%b %d %Y "))
# Out:
# May 06 2019
